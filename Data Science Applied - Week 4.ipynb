# %% [markdown]
# ## 1. A description of the problem and a discussion of the background.

# %% [markdown]
# ##### There had been, during the last years, a growing interest for vegetarian and vegan diets.  That has impacted in the number of restaurants specialised in this kind of food.

# %% [markdown]
# ##### However, in relative terms, the number of “veggi” ( veggi = vegetarian + vegan) restaurants compared to the regular ones is still low.

# %% [markdown]
# ##### The idea of this analysis is to find, in Toronto, which areas are the best to open a new veggi restaurant. To do that, I have to check in which areas there are a high number of restaurants (because it would imply a high numbers of potential clients) and low ratio of veggi restaurants / total restaurants (to avoid unnecessary competitiveness

# %% [markdown]
# ## 2. A description of the data and how it will be used to solve the problem.

# %% [markdown]
# ### 2.1 ) Three main sources will be used mainly:

# %% [markdown]
# ##### a) The list of canadian Zip Codes and neighbourhoods that we can find in Wikipedia: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# ##### b) The list of canadian Zip Codes with their latitudes and longitudes that we can find in: http://cocl.us/Geospatial_data

# %% [markdown]
# ##### c) API Foursquare: I will make calls to get venues, restaurants to complete the analysis and answer the question.

# %% [markdown]
# ### 2.2) How the data will be used:

# %% [markdown]
# ##### 1. I will merge the dataset with the zip codes and the neighbourhoods and the one with the zip codes and the coordinates to have a dataset with all these fields.

# %% [markdown]
# ##### 2. I will use API foursquare to make calls to retrieve venues with their coordinates and with all the information related to the restaurants around these venues.

# %% [markdown]
# ##### 3. Then I will be able to count the number of veggie and total restaurants in each venue and thanks theirs coordinates I will be visualize them on a map.

# %% [markdown]
# ##### 4. I will split Toronto in a specific (k) number of areas applying KMeans.

# %% [markdown]
# ##### 5. I will determinate the frequency in each area and/or venues to check where could be the best place to open a new “veggie” restaurant
